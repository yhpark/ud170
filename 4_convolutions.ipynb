# %% [markdown]
# Deep Learning
# =============
#
# Assignment 4
# ------------
#
# Previously in `2_fullyconnected.ipynb` and `3_regularization.ipynb`, we trained fully connected networks to classify [notMNIST](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html) characters.
#
# The goal of this assignment is make the neural network convolutional.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)

# %% [markdown]
# Reformat into a TensorFlow-friendly shape:
# - convolutions need the image data formatted as a cube (width by height by #channels)
# - labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
  dataset = dataset.reshape(
    (-1, image_size, image_size, num_channels)).astype(np.float32)
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28, 1) (200000, 10)
# Validation set (10000, 28, 28, 1) (10000, 10)
# Test set (10000, 28, 28, 1) (10000, 10)

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# Let's build a small network with two convolutional layers, followed by one fully connected layer. Convolutional networks are more expensive computationally, so we'll limit its depth and number of fully connected nodes.

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 4.263349
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 2.120667
# Minibatch accuracy: 18.8%
# Validation accuracy: 23.4%
# Minibatch loss at step 100: 1.102169
# Minibatch accuracy: 62.5%
# Validation accuracy: 60.6%
# Minibatch loss at step 150: 0.689419
# Minibatch accuracy: 75.0%
# Validation accuracy: 74.6%
# Minibatch loss at step 200: 0.866627
# Minibatch accuracy: 68.8%
# Validation accuracy: 76.2%
# Minibatch loss at step 250: 1.190392
# Minibatch accuracy: 62.5%
# Validation accuracy: 77.5%
# Minibatch loss at step 300: 0.414434
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.6%
# Minibatch loss at step 350: 0.548127
# Minibatch accuracy: 87.5%
# Validation accuracy: 77.3%
# Minibatch loss at step 400: 0.235475
# Minibatch accuracy: 100.0%
# Validation accuracy: 79.4%
# Minibatch loss at step 450: 1.138644
# Minibatch accuracy: 75.0%
# Validation accuracy: 78.8%
# Minibatch loss at step 500: 0.914781
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.9%
# Minibatch loss at step 550: 1.049427
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.8%
# Minibatch loss at step 600: 0.306368
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.2%
# Minibatch loss at step 650: 0.937729
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.7%
# Minibatch loss at step 700: 0.813381
# Minibatch accuracy: 68.8%
# Validation accuracy: 81.4%
# Minibatch loss at step 750: 0.069068
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.2%
# Minibatch loss at step 800: 0.644581
# Minibatch accuracy: 68.8%
# Validation accuracy: 81.9%
# Minibatch loss at step 850: 1.123486
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.6%
# Minibatch loss at step 900: 0.717346
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.8%
# Minibatch loss at step 950: 0.539319
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.9%
# Minibatch loss at step 1000: 0.369305
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.3%
# Test accuracy: 89.2%

# %% [markdown]
# ---
# Problem 1
# ---------
#
# The convolutional model above uses convolutions with stride 2 to reduce the dimensionality. Replace the strides by a max pooling operation (`nn.max_pool()`) of stride 2 and kernel size 2.
#
# ---

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    pool = tf.nn.max_pool(hidden, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
    conv = tf.nn.conv2d(pool, layer2_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    pool = tf.nn.max_pool(hidden, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
    shape = pool.get_shape().as_list()
    reshape = tf.reshape(pool, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 4.178954
# Minibatch accuracy: 12.5%
# Validation accuracy: 11.2%
# Minibatch loss at step 50: 1.527009
# Minibatch accuracy: 43.8%
# Validation accuracy: 56.4%
# Minibatch loss at step 100: 1.063629
# Minibatch accuracy: 62.5%
# Validation accuracy: 64.9%
# Minibatch loss at step 150: 0.520347
# Minibatch accuracy: 75.0%
# Validation accuracy: 73.1%
# Minibatch loss at step 200: 0.979092
# Minibatch accuracy: 75.0%
# Validation accuracy: 75.9%
# Minibatch loss at step 250: 1.286275
# Minibatch accuracy: 56.2%
# Validation accuracy: 76.9%
# Minibatch loss at step 300: 0.319079
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.6%
# Minibatch loss at step 350: 0.670547
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.3%
# Minibatch loss at step 400: 0.187555
# Minibatch accuracy: 100.0%
# Validation accuracy: 80.2%
# Minibatch loss at step 450: 0.884172
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.3%
# Minibatch loss at step 500: 0.611520
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.7%
# Minibatch loss at step 550: 0.908580
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.9%
# Minibatch loss at step 600: 0.387379
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.2%
# Minibatch loss at step 650: 0.955159
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.8%
# Minibatch loss at step 700: 0.779174
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 750: 0.119497
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.3%
# Minibatch loss at step 800: 0.593080
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.3%
# Minibatch loss at step 850: 0.969822
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.8%
# Minibatch loss at step 900: 0.556473
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.0%
# Minibatch loss at step 950: 0.471655
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.5%
# Minibatch loss at step 1000: 0.316031
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.9%
# Test accuracy: 90.5%

# %% [markdown]
# ---
# Problem 2
# ---------
#
# Try to get the best performance you can using a convolutional net. Look for example at the classic [LeNet5](http://yann.lecun.com/exdb/lenet/) architecture, adding Dropout, and/or adding learning rate decay.
#
# ---

# %%
batch_size = 64
patch_size = 5
layer1_depth = 16
layer2_depth = 32
num_hidden = 128
dropout_keep_prob = 0.5
l2_reg_coeff = 0.0001

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, layer1_depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([layer1_depth]))

  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, layer1_depth, layer2_depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[layer2_depth]))

  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * layer2_depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))

  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data, is_train):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    if is_train:
        hidden = tf.nn.dropout(hidden, keep_prob=dropout_keep_prob)
    pool = tf.nn.max_pool(hidden, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
    conv = tf.nn.conv2d(pool, layer2_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    if is_train:
        hidden = tf.nn.dropout(hidden, keep_prob=dropout_keep_prob)
    pool = tf.nn.max_pool(hidden, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
    shape = pool.get_shape().as_list()
    reshape = tf.reshape(pool, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset, is_train=True)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits) + \
      l2_reg_coeff * (tf.nn.l2_loss(layer1_weights) + tf.nn.l2_loss(layer1_biases) + \
                     tf.nn.l2_loss(layer2_weights) + tf.nn.l2_loss(layer2_biases)))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset, is_train=False))
  test_prediction = tf.nn.softmax(model(tf_test_dataset, is_train=False))

# %%
num_steps = 3001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 8.758324
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.5%
# Minibatch loss at step 50: 1.242880
# Minibatch accuracy: 60.9%
# Validation accuracy: 70.2%
# Minibatch loss at step 100: 0.621471
# Minibatch accuracy: 84.4%
# Validation accuracy: 76.6%
# Minibatch loss at step 150: 0.617761
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.1%
# Minibatch loss at step 200: 0.733601
# Minibatch accuracy: 79.7%
# Validation accuracy: 79.8%
# Minibatch loss at step 250: 0.606965
# Minibatch accuracy: 82.8%
# Validation accuracy: 78.8%
# Minibatch loss at step 300: 1.008256
# Minibatch accuracy: 68.8%
# Validation accuracy: 81.0%
# Minibatch loss at step 350: 0.537707
# Minibatch accuracy: 84.4%
# Validation accuracy: 81.4%
# Minibatch loss at step 400: 0.764920
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.2%
# Minibatch loss at step 450: 0.586325
# Minibatch accuracy: 84.4%
# Validation accuracy: 82.1%
# Minibatch loss at step 500: 0.265571
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.9%
# Minibatch loss at step 550: 0.480688
# Minibatch accuracy: 85.9%
# Validation accuracy: 82.9%
# Minibatch loss at step 600: 0.703531
# Minibatch accuracy: 73.4%
# Validation accuracy: 83.1%
# Minibatch loss at step 650: 0.527764
# Minibatch accuracy: 82.8%
# Validation accuracy: 84.0%
# Minibatch loss at step 700: 0.523718
# Minibatch accuracy: 82.8%
# Validation accuracy: 83.1%
# Minibatch loss at step 750: 0.447604
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.0%
# Minibatch loss at step 800: 0.618822
# Minibatch accuracy: 82.8%
# Validation accuracy: 83.2%
# Minibatch loss at step 850: 0.682296
# Minibatch accuracy: 82.8%
# Validation accuracy: 84.0%
# Minibatch loss at step 900: 0.648069
# Minibatch accuracy: 85.9%
# Validation accuracy: 83.6%
# Minibatch loss at step 950: 0.357542
# Minibatch accuracy: 90.6%
# Validation accuracy: 84.0%
# Minibatch loss at step 1000: 0.415655
# Minibatch accuracy: 89.1%
# Validation accuracy: 84.0%
# Minibatch loss at step 1050: 0.392976
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.6%
# Minibatch loss at step 1100: 0.839257
# Minibatch accuracy: 78.1%
# Validation accuracy: 84.2%
# Minibatch loss at step 1150: 0.437694
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.4%
# Minibatch loss at step 1200: 0.454405
# Minibatch accuracy: 85.9%
# Validation accuracy: 84.3%
# Minibatch loss at step 1250: 0.691624
# Minibatch accuracy: 79.7%
# Validation accuracy: 84.2%
# Minibatch loss at step 1300: 0.330489
# Minibatch accuracy: 92.2%
# Validation accuracy: 84.2%
# Minibatch loss at step 1350: 0.726962
# Minibatch accuracy: 78.1%
# Validation accuracy: 84.1%
# Minibatch loss at step 1400: 0.760139
# Minibatch accuracy: 76.6%
# Validation accuracy: 84.8%
# Minibatch loss at step 1450: 0.438267
# Minibatch accuracy: 89.1%
# Validation accuracy: 84.9%
# Minibatch loss at step 1500: 0.575997
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.4%
# Minibatch loss at step 1550: 0.810553
# Minibatch accuracy: 76.6%
# Validation accuracy: 84.3%
# Minibatch loss at step 1600: 0.215852
# Minibatch accuracy: 95.3%
# Validation accuracy: 84.8%
# Minibatch loss at step 1650: 0.413595
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.8%
# Minibatch loss at step 1700: 0.621841
# Minibatch accuracy: 85.9%
# Validation accuracy: 85.0%
# Minibatch loss at step 1750: 0.757138
# Minibatch accuracy: 76.6%
# Validation accuracy: 85.1%
# Minibatch loss at step 1800: 0.519043
# Minibatch accuracy: 85.9%
# Validation accuracy: 84.6%
# Minibatch loss at step 1850: 0.433993
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.3%
# Minibatch loss at step 1900: 0.540623
# Minibatch accuracy: 84.4%
# Validation accuracy: 85.0%
# Minibatch loss at step 1950: 0.400321
# Minibatch accuracy: 89.1%
# Validation accuracy: 85.3%
# Minibatch loss at step 2000: 0.325225
# Minibatch accuracy: 89.1%
# Validation accuracy: 85.2%
# Minibatch loss at step 2050: 0.456434
# Minibatch accuracy: 89.1%
# Validation accuracy: 85.8%
# Minibatch loss at step 2100: 0.248065
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.4%
# Minibatch loss at step 2150: 0.317433
# Minibatch accuracy: 89.1%
# Validation accuracy: 85.3%
# Minibatch loss at step 2200: 0.509092
# Minibatch accuracy: 85.9%
# Validation accuracy: 85.9%
# Minibatch loss at step 2250: 0.454331
# Minibatch accuracy: 85.9%
# Validation accuracy: 86.1%
# Minibatch loss at step 2300: 0.609649
# Minibatch accuracy: 84.4%
# Validation accuracy: 85.4%
# Minibatch loss at step 2350: 0.565926
# Minibatch accuracy: 82.8%
# Validation accuracy: 85.8%
# Minibatch loss at step 2400: 0.470612
# Minibatch accuracy: 90.6%
# Validation accuracy: 85.1%
# Minibatch loss at step 2450: 0.492335
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.0%
# Minibatch loss at step 2500: 0.447734
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.9%
# Minibatch loss at step 2550: 0.368851
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.2%
# Minibatch loss at step 2600: 0.373025
# Minibatch accuracy: 90.6%
# Validation accuracy: 85.6%
# Minibatch loss at step 2650: 0.350251
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.1%
# Minibatch loss at step 2700: 0.631448
# Minibatch accuracy: 79.7%
# Validation accuracy: 86.0%
# Minibatch loss at step 2750: 0.291205
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.0%
# Minibatch loss at step 2800: 0.530446
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.2%
# Minibatch loss at step 2850: 0.310346
# Minibatch accuracy: 89.1%
# Validation accuracy: 85.8%
# Minibatch loss at step 2900: 0.602177
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.3%
# Minibatch loss at step 2950: 0.428482
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.5%
# Minibatch loss at step 3000: 0.522901
# Minibatch accuracy: 85.9%
# Validation accuracy: 86.1%
# Test accuracy: 92.9%
